# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt

# %%
alunos = pd.read_csv('./2022.1/alunos.csv', header = None)
alunos.rename(columns= {0: 'Num', 1:'Matricula', 2:'Nome'}, inplace= True)

# %%
emails = pd.read_csv('./2022.1/lista_emails_ARQA25_020200.txt', sep=';',header = None).drop([1], axis=1)
emails.rename(columns = {0:'Mail'}, inplace = True)
emails
# Out:
#                             Mail
# 0       beatriz.cristina@ufba.br
# 1                 edlasm@ufba.br
# 2      nandi.cardoso16@gmail.com
# 3               gbnb1@bol.com.br
# 4       lopesglaucia11@gmail.com
# 5          iago.nudelman@ufba.br
# 6              indysimas@ufba.br
# 7         ivinalorenja@gmail.com
# 8        jiselle.sdias@gmail.com
# 9   roberto_filho123@hotmail.com
# 10     leticialima0511@gmail.com
# 11      maria.anunciacao@ufba.br
# 12     raissarosario10@gmail.com
# 13              renatars@ufba.br
# 14      serginhosena87@gmail.com
# 15          tomazfsl@outlook.com
# 16          wilton.costa@ufba.br
# 17         breno.menezes@ufba.br

# %%
alun_mail = alunos.join(emails)
alun_mail
# Out:
#      Num    Matricula                                Nome  \
# 0    1.0  219120468.0  BEATRIZ CRISTINA SANTOS DE SANTANA
# 1    2.0  219116400.0              EDLA DA SILVA MARCIANO
# 2    3.0  220118518.0       FERNANDA MARIA ARAGAO CARDOSO
# 3    4.0  216119222.0              GILBERTO NUNES BARRETO
# 4    5.0  220115820.0        GLAUCIA SILVA LOPES DE JESUS
# 5    6.0  220115835.0         IAGO NUDELMAN REIS YAMAMOTO
# 6    7.0  220120359.0    INDIARA SIMAS RODRIGUES DE SOUZA
# 7    8.0  219120460.0           IVINA LOREN JESUS ALMEIDA
# 8    9.0  220115829.0     JISELLE DIAS DOS SANTOS SANTANA
# 9   10.0  220119526.0   JOSE ROBERTO BORGES BATISTA FILHO
# 10  10.0  219122850.0             LETICIA LIMA DE ALMEIDA
# 11  12.0  220119520.0     MARIA JANAINA ANUNCIACAO VENTIN
# 12  13.0  220115826.0              RAISSA LIMA DO ROSARIO
# 13  14.0  220115822.0         RENATA RODRIGUES DOS SANTOS
# 14  15.0  221119680.0    SERGIO PINHEIRO DOS SANTOS FILHO
# ...
